# %%
import importlib, time
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import numpy as np

import ClassParticle2D
importlib.reload(ClassParticle2D)
from ClassParticle2D import Particle

T = 10
dt = 0.1
t_now = 0.0
mol = Particle(velocity=[3,5])
print(type(t_now), type(dt))

while t_now < T:
    clear_output(wait=True)

    mol.pos += dt*mol.vel

    plt.ion()
    fig, ax = plt.subplots()
    ax.set_xlim([-50,50])
    ax.set_ylim([-50,50])
    ax.scatter(mol.pos[0], mol.pos[0])
    t_now += dt
    time.sleep(0.00001)
    plt.show()
# mols = [for i in range]
